# %%
import os
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as la

# %%
df = pd.read_csv('data.csv')
df.columns = ['x','y','h']
print(df)
# Out:
#               x        y     h
# 0        263553  4987329  2375
# 1        263619  4987327  2382
# 2        263685  4987324  2392
# 3        263751  4987322  2409
# 4        263816  4987319  2434
# ...         ...      ...   ...
# 1442396  339383  4873823   821
# 1442397  339450  4873822   837
# 1442398  339516  4873820   822
# 1442399  339583  4873818   800
# 1442400  339650  4873817   773
#
# [1442401 rows x 3 columns]

# %%
df2 = pd.read_csv('data2.csv')
df2.columns = ['x','y','h']

# %%
df2 = df2.iloc[::16,:]

# %%
df = df.iloc[::16,:]

# %%
ax1 = df.plot.scatter(x='x', y='y', c='h')
ax2 = df2.plot.scatter(x='x', y='y', c='h')

# %%
df_join = df.append(df2)

# %%
ax2 = df_join.plot.scatter(x='x', y='y', c='h')

# %%
df['h']
# Out:
# 0          2375
# 16         2651
# 32         2358
# 48         2059
# 64         1735
#            ...
# 1442336    1193
# 1442352     978
# 1442368     729
# 1442384     601
# 1442400     773
# Name: h, Length: 90151, dtype: int64

# %%
color = []
for i in range(len(df)):
    color.append(df['h'].iloc[i]<1800)

# %%
ax1 = df.plot.scatter(x='x', y='y', c=color)
